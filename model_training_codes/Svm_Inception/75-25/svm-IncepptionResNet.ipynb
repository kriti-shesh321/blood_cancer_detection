# %%
import numpy as np 
import matplotlib.pyplot as plt
import glob
import cv2

import os
from keras.applications.inception_resnet_v2 import InceptionResNetV2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Read input images and assign labels based on folder names
print(os.listdir("/content/drive/MyDrive/Project/projectdatasets"))

SIZE = 128  #Resize images
# Out:
# ['test', 'train']

# %%
#Capture training data and labels into respective lists
train_images = []
train_labels = [] 

for directory_path in glob.glob("/content/drive/MyDrive/Project/projectdatasets/train/*"):
    label = directory_path.split("/")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(directory_path, "*")):
        #print(img_path)
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)       
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        train_images.append(img)
        train_labels.append(label)

#Convert lists to arrays        
train_images = np.array(train_images)
train_labels = np.array(train_labels)
# Out:
# Leukemia
# Myeloma
# Normal

# %%
train_images.shape
# Out:
# (4500, 128, 128, 3)

# %%
# Capture test/validation data and labels into respective lists

test_images = []
test_labels = [] 
for directory_path in glob.glob("/content/drive/MyDrive/Project/projectdatasets/test/*"):
    fruit_label = directory_path.split("/")[-1]
    for img_path in glob.glob(os.path.join(directory_path, "*")):
        img = cv2.imread(img_path, cv2.IMREAD_COLOR)
        img = cv2.resize(img, (SIZE, SIZE))
        img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
        test_images.append(img)
        test_labels.append(fruit_label)

#Convert lists to arrays                
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %%
test_images.shape
# Out:
# (1500, 128, 128, 3)

# %%
np.unique(train_labels)
# Out:
# array(['Leukemia', 'Myeloma', 'Normal'], dtype='<U8')

# %%
#Encode labels from text to integers.
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
print(np.unique(train_labels_encoded))
# Out:
# [0 1 2]

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, y_train, x_test, y_test = train_images, train_labels_encoded, test_images, test_labels_encoded

# %%
#Normalize pixel values to between 0 and 1
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
#Load model wothout classifier/fully connected layers
Irn_model = InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, 3))

#Make loaded layers as non-trainable. This is important as we want to work with pre-trained weights
for layer in Irn_model.layers:
	layer.trainable = False
    
Irn_model.summary()  #Trainable parameters will be 0
# Out:
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_203 (Conv2D)            (None, 63, 63, 32)   864         ['input_2[0][0]']
#
#  batch_normalization_203 (Batch  (None, 63, 63, 32)  96          ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 63, 63, 32)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 61, 61, 32)   9216        ['activation_203[0][0]']
#
#  batch_normalization_204 (Batch  (None, 61, 61, 32)  96          ['conv2d_204[0][0]']
#  Normalization)
#
#  activation_204 (Activation)    (None, 61, 61, 32)   0           ['batch_normalization_204[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 61, 61, 64)   18432       ['activation_204[0][0]']
#
#  batch_normalization_205 (Batch  (None, 61, 61, 64)  192         ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_205 (Activation)    (None, 61, 61, 64)   0           ['batch_normalization_205[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 30, 30, 64)  0           ['activation_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 30, 30, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 30, 30, 80)  240         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 30, 30, 80)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 28, 28, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 28, 28, 192)  576        ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 28, 28, 192)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 192)  0          ['activation_207[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 13, 13, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 13, 13, 64)  192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 13, 13, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 13, 13, 96)   55296       ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 13, 13, 48)  144         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 13, 13, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 13, 13, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_208 (Conv2D)            (None, 13, 13, 96)   18432       ['max_pooling2d_5[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 13, 13, 64)   76800       ['activation_209[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 13, 13, 96)   82944       ['activation_212[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 13, 13, 64)   12288       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 13, 13, 96)  288         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 13, 13, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 13, 13, 96)  288         ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 13, 13, 64)  192         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 13, 13, 96)   0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 13, 13, 320)  0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 13, 13, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 13, 13, 32)  96          ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 13, 13, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 13, 13, 32)  96          ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 13, 13, 48)  144         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_219[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 13, 13, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_216[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 13, 13, 32)  96          ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 13, 13, 32)  96          ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 13, 13, 64)  192         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 13, 13, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 13, 13, 320)  0           ['block35_1[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 13, 13, 32)  96          ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 13, 13, 32)  96          ['conv2d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 13, 13, 48)  144         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_225[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_222[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 13, 13, 32)  96          ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 13, 13, 32)  96          ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 13, 13, 64)  192         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 13, 13, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 13, 13, 320)  0           ['block35_2[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 13, 13, 32)  96          ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_230[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 13, 13, 32)  96          ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 13, 13, 48)  144         ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_228[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 13, 13, 32)  96          ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 13, 13, 32)  96          ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 13, 13, 64)  192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 13, 13, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 13, 13, 320)  0           ['block35_3[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 13, 13, 32)  96          ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_236[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 13, 13, 32)  96          ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 13, 13, 48)  144         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_237[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_234[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 13, 13, 32)  96          ['conv2d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 13, 13, 32)  96          ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 13, 13, 64)  192         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 13, 13, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 13, 13, 320)  0           ['block35_4[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 13, 13, 32)  96          ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_242[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 13, 13, 32)  96          ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 13, 13, 48)  144         ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_240[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 13, 13, 32)  96          ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 13, 13, 32)  96          ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 13, 13, 64)  192         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 13, 13, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 13, 13, 320)  0           ['block35_5[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 13, 13, 32)  96          ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_248[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 13, 13, 32)  96          ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 13, 13, 48)  144         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_246[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 13, 13, 32)  96          ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 13, 13, 32)  96          ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 13, 13, 64)  192         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 13, 13, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 13, 13, 320)  0           ['block35_6[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 13, 13, 32)  96          ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 13, 13, 32)  96          ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 13, 13, 48)  144         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 13, 13, 48)   0           ['batch_normalization_255[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 13, 13, 32)   9216        ['activation_252[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 13, 13, 64)   27648       ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 13, 13, 32)  96          ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 13, 13, 32)  96          ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 13, 13, 64)  192         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 13, 13, 64)   0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 13, 13, 128)  0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 13, 13, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 13, 13, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 13, 13, 320)  0           ['block35_7[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_260 (Batch  (None, 13, 13, 32)  96          ['conv2d_260[0][0]']
#  Normalization)
#
#  activation_260 (Activation)    (None, 13, 13, 32)   0           ['batch_normalization_260[0][0]']
#
#  conv2d_258 (Conv2D)            (None, 13, 13, 32)   10240       ['block35_7_ac[0][0]']
#
#  conv2d_261 (Conv2D)            (None, 13, 13, 48)   13824       ['activation_260[0][0]']
#
# ...
#
#  conv2d_391 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_6_ac[0][0]']
#
#  batch_normalization_391 (Batch  (None, 2, 2, 192)   576         ['conv2d_391[0][0]']
#  Normalization)
#
#  activation_391 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_391[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 2, 2, 224)    129024      ['activation_391[0][0]']
#
#  batch_normalization_392 (Batch  (None, 2, 2, 224)   672         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 2, 2, 224)    0           ['batch_normalization_392[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 2, 2, 256)    172032      ['activation_392[0][0]']
#
#  batch_normalization_390 (Batch  (None, 2, 2, 192)   576         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 2, 2, 256)   768         ['conv2d_393[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 2, 2, 448)    0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 2, 2, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 2, 2, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 2, 2, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 2, 2, 192)   576         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_395[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 2, 2, 224)    129024      ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 2, 2, 224)   672         ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 2, 2, 224)    0           ['batch_normalization_396[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 2, 2, 256)    172032      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 2, 2, 192)   576         ['conv2d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 2, 2, 256)   768         ['conv2d_397[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 2, 2, 448)    0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 2, 2, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 2, 2, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 2, 2, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 2, 2, 192)   576         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 2, 2, 224)    129024      ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 2, 2, 224)   672         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 2, 2, 224)    0           ['batch_normalization_400[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 2, 2, 256)    172032      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 2, 2, 192)   576         ['conv2d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 2, 2, 256)   768         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 2, 2, 448)    0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 2, 2, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 2, 2, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 2, 2, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 2, 2, 192)   576         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 2, 2, 224)    129024      ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 2, 2, 224)   672         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 2, 2, 224)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 2, 2, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 2, 2, 256)    172032      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 2, 2, 192)   576         ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 2, 2, 256)   768         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 2, 2, 192)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 2, 2, 256)    0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 2, 2, 448)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 2, 2, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 2, 2, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 2, 2, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 2, 2, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 2, 2, 1536)   0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 0
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________

# %%
#Now, let us use features from convolutional network for RF
feature_extractor = Irn_model.predict(x_train)

features = feature_extractor.reshape(feature_extractor.shape[0], -1)

X_for_training = features #This is our X input to RF

# %%
X_for_training.shape
# Out:
# (4500, 6144)

# %%
#svm
from sklearn.svm import SVC
model = SVC(kernel='poly', gamma=0.5, C=0.1)
model.fit(X_for_training, y_train) #For sklearn no one hot encoding
# Out:
# SVC(C=0.1, gamma=0.5, kernel='poly')

# %%
#Send test data through same feature extractor process
X_test_feature = Irn_model.predict(x_test)
print(X_test_feature.shape)
# Out:
# (1500, 2, 2, 1536)

# %%
X_test_features = X_test_feature.reshape(X_test_feature.shape[0], -1)

# %%
print(X_test_feature.shape)
# Out:
# (1500, 2, 2, 1536)

# %%
print(X_test_features.shape)
# Out:
# (1500, 6144)

# %%
#Now predict using the trained RF model. 
prediction = model.predict(X_test_features)
#Inverse le transform to get original label back. 
prediction = le.inverse_transform(prediction)

# %%
print(prediction)
# Out:
# ['Normal' 'Leukemia' 'Normal' ... 'Myeloma' 'Myeloma' 'Myeloma']

# %%
#Print overall accuracy
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, prediction))
# Out:
# Accuracy =  0.8313333333333334

# %% [markdown]
# **Precision Score , Recall Score , Accuracy Score , F1 Score**

# %%
#Precision Score
print("Precision = ", metrics.precision_score(test_labels, prediction,average='micro'))

#Recall
print("Recall = ", metrics.recall_score(test_labels, prediction,average='micro'))

#Accuracy Score
print("Accuracy = ", metrics.accuracy_score(test_labels, prediction))

#F1 score
print("F1 Score = ", metrics.f1_score(test_labels, prediction,average='micro'))
# Out:
# Precision =  0.8313333333333334
# Recall =  0.8313333333333334
# Accuracy =  0.8313333333333334
# F1 Score =  0.8313333333333334

# %% [markdown]
# **Confusion Matrix**

# %%
#Confusion Matrix - verify accuracy of each class
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(test_labels, prediction)
#print(cm)
sns.heatmap(cm, annot=True)
plt.xlabel('Predictions', fontsize=18)
plt.ylabel('Actuals', fontsize=18)
plt.show()

# %%
print(test_labels)
# Out:
# ['Normal' 'Normal' 'Normal' ... 'Myeloma' 'Myeloma' 'Myeloma']

# %%
print(prediction)
# Out:
# ['Normal' 'Leukemia' 'Normal' ... 'Myeloma' 'Myeloma' 'Myeloma']

# %%
cm = confusion_matrix(test_labels, prediction)
print(cm)
# Out:
# [[344   0 156]
#  [  5 495   0]
#  [ 91   1 408]]

# %%
#Check results on a few select images
n=np.random.randint(0, x_test.shape[0])
img = x_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
input_img_feature=Irn_model.predict(input_img)
input_img_features=input_img_feature.reshape(input_img_feature.shape[0], -1)
prediction = model.predict(input_img_features)[0]
prediction = le.inverse_transform([prediction])  #Reverse the label encoder to original name
print("The prediction for this image is: ", prediction)
print("The actual label for this image is: ", test_labels[n])
# Out:
# The prediction for this image is:  ['Normal']
# The actual label for this image is:  Normal

# %%
from joblib import Parallel, delayed
import joblib
import pickle

# %%
# Save the model as a pickle in a file
pickle.dump(model, open('svm_Irn.pkl',"wb"))

# %%
model1 = pickle.load(open('svm_Irn.pkl',"rb"))

# %%
import shutil 
shutil.copy('/content/svm_Irn.pkl','/content/drive/MyDrive/Project/Colab Notebooks/New datasets/svm+Inception/75 25/svmIRN.h5')
# Out:
# '/content/drive/MyDrive/Project/Colab Notebooks/New datasets/svm+Inception/svmIRN'
